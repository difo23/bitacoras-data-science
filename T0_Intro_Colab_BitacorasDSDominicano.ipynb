# %% [markdown]
# <a href="https://colab.research.google.com/github/difo23/BitacorasDataScienceDominicano/blob/master/T0_Intro_Colab_BitacorasDSDominicano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bitácora de un Data Scientist Dominicano:
#
# ---
#
#
# ## Intro a Colab
#
#  0. Vistazo general a la interfaz y Modificar la apariencia de colab.
#  1. Uso de atajos de teclado importantes en Colab.
#  2. Introduccion a comandos de bash.
#  3. Agregar Dataset repositorio local.
#  4. Agregar DataSet por URL.

# %% [markdown]
# ## 1. Uso de atajos de teclado importantes en Colab:

# %% [markdown]
# ### Seleccionar atajos clasicos de notebook:
# En la  pestaña Herramientas/Preferencias/Editor +  enlaces claves Editor

# %% [markdown]
# ### Mostrar todos los atajos de teclado:
# CTRL + M H

# %% [markdown]
# ### Crear una nueva celda de texto:
# CTRL+M X ; Este atajo lo agregue yo mismo.

# %% [markdown]
# ### Crear titulos en celda de texto:
#   * Agregas al principio de la línea el caracter '#' para encabezado H1.
#   * Los caracteres '##' para encabezado H2, así sucesivamente hasta H6.

# %% [markdown]
# ### Crear una nueva celda de codígo:
# CTRL+M C

# %%
# Esta es una linea de codigo creada con el comando anterior

# %%
 a = 24

# %%
a
# Out:
# 24

# %%
Out[3] #Puedo referirme a una salida usando el arreglo globa 'Out'
# Out:
# 24

# %%
In[2] # Puedo referirme a una entrada usando el arreglo global 'In'

# %% [markdown]
# ### Covertir una celda de codigo en una celda de texto:
# CTRL+M M

# %% [markdown]
# ### Convertir una celda de texto en una celda de codigo:
# CTRL + M Y

# %% [markdown]
# ### Ejecutar una linea de codigo y agregar una nueva linea:
# ALT + Enter

# %% [markdown]
# ### Ejecutar una celda y saltar a la siguiente:
# SHIFT + Enter

# %% [markdown]
# ### Ejecutar una celda de codigo:
# CTRL + Enter

# %%
a
# Out:
# 24

# %% [markdown]
# ### Agregar una nueva celda encima de la que te encuentras:
# CTRL + M A
#
# > Bloc con sangría

# %%
# Nueva linea encima

# %%
# Linea actual

# %%
# Nueva linea debajo

# %% [markdown]
# ### Agregar una nueva celda debajo de la que te encuentras:
# CTRL + M B

# %% [markdown]
# ### Usar snippet para insertar grafico:

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

import altair as alt

points = alt.Chart(cars).mark_point().encode(
  x='Year:T',
  y='Miles_per_Gallon',
  color='Origin'
).properties(
  width=800
)

lines = alt.Chart(cars).mark_line().encode(
  x='Year:T',
  y='mean(Miles_per_Gallon)',
  color='Origin'
).properties(
  width=800
).interactive(bind_y=False)
              
points + lines
# Out:
# LayerChart({
#   data:      Acceleration  Cylinders  Displacement  ...  Origin  Weight_in_lbs       Year
#   0            12.0          8         307.0  ...     USA           3504 1970-01-01
#   1            11.5          8         350.0  ...     USA           3693 1970-01-01
#   2            11.0          8         318.0  ...     USA           3436 1970-01-01
#   3            12.0          8         304.0  ...     USA           3433 1970-01-01
#   4            10.5          8         302.0  ...     USA           3449 1970-01-01
#   5            10.0          8         429.0  ...     USA           4341 1970-01-01
#   6             9.0          8         454.0  ...     USA           4354 1970-01-01
#   7             8.5          8         440.0  ...     USA           4312 1970-01-01
#   8            10.0          8         455.0  ...     USA           4425 1970-01-01
#   9             8.5          8         390.0  ...     USA           3850 1970-01-01
# ...

# %% [markdown]
# ## 1.1 Conexión a entorno local:

# %% [markdown]
# * pip install jupyter_http_over_ws
# * jupyter serverextension enable --py jupyter_http_over_ws

# %% [markdown]
# jupyter notebook \
#   --NotebookApp.allow_origin='https://colab.research.google.com' \
#   --port=8888 \
#   --NotebookApp.port_retries=0

# %% [markdown]
# ## 2. Introducción a comandos de Bash:
# [Manual de Bash](https://es.wikibooks.org/wiki/El_Manual_de_BASH_Scripting_B%C3%A1sico_para_Principiantes/Comandos_b%C3%A1sicos_de_una_shell)

# %% [markdown]
# ### Agregar my drive en el alojamiento remoto:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Comando '***PWD***' para indicar donde me encuentro:

# %%
# !pwd
# Out:
# /content/drive

# %%
pwd = !pwd

# %%
type(pwd)
pwd
# Out:
# ['/content/drive']

# %% [markdown]
# ### Commando ***'ls'*** para listar el contenido de la carpeta en la que me encuentro:

# %%
# !ls
# los comandos de bash linux o powershell son los mismo aqui si pones ! delante 
#del comando
# Out:
# 'My Drive'

# %%
a = !ls

# %%
type ( a)
# Out:
# IPython.utils.text.SList

# %%
a[0]
a
# Out:
# ["'My Drive'"]

# %%
# %ls
# Out:
# 'My Drive'/

# %%
**a** = %ls
type(a)
a

# %%
ls
# Out:
# 'My Drive'/

# %% [markdown]
# ### Comando 'cd' para cambiar de directorio pasandole un path:

# %%
# !cd ..

# %%
# !ls
# Out:
# 'My Drive'

# %%
# %cd ..
# Out:
# /content

# %%
ls # puedo usar el comando sin !
# Out:
# drive/  sample_data/

# %% [markdown]
# ## 2.1 LaTex

# %% [markdown]
# $a= 12 + n*10$

# %% [markdown]
# ## 3. Insertar Dataset repositorio local;
#     1. Dirigete a la flecha en la esquina superior izquierda, da clic.
#     2. Selecciona archivos.
#     3. Selecciona Subir.

# %% [markdown]
# ## 4. Agregar DataSet por URL.

# %%
pwd
# Out:
# ['/content/drive/My Drive/Colab Notebooks']

# %%
ls
# Out:
# DataSets/                                INTRO_COLAB.ipynb
# Intro_Colab_BitacorasDSDominicano.ipynb  Notebooks/

# %%
cd DataSets/
# Out:
# /content/drive/My Drive/Colab Notebooks/DataSets

# %%
ls # la carpeta esta limpia

# %% [markdown]
# El siguiente codigo lo tomamos de este articulo [Introducción a Google Colab para data science](https://www.datahack.es/introduccion-a-google-colab-para-data-science/)

# %%
# !wget -cq https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip

# %%
ls
# Out:
# flower_data.zip

# %%
# !unzip -qq flower_data.zip

# %%
ls
# Out:
# flower_data/  flower_data.zip

# %%
cd flower_data/
# Out:
# [Errno 2] No such file or directory: 'flower_data/'
# /content/drive/My Drive/Colab Notebooks/DataSets/flower_data

# %%
# !ls
# Out:
# '=0.0.1a3'		        logicasecuenciapaso4.png
#  anaconda3		        logicasecuenciapaso4.png~
#  Arduino		        materias%202018-2019.ods_0.ods
#  arduino_curso.osp	        MEGA
#  Audio			       'MEGAsync Downloads'
#  bin			        mozilla2.pdf
#  Desktop		        mozilla3.pdf
#  Documents		        mozilla4.pdf
#  Downloads		        mozilla5.pdf
#  drive.osp		        mozilla6.pdf
#  droidcam-bit.tar.bz2	        mozilla.pdf
#  Dropbox		        Music
#  env			        MyPaint
#  examples.desktop	        nxj.cache
#  exercism		        pcb
#  grive			        Pictures
#  historia.osp		       "PlayOnLinux's virtual drives"
#  hs_err_pid3136.log	        Public
#  hs_err_pid5295.log	        PycharmProjects
#  IdeaProjects		        R
#  iverilog		       'Recovered file from 2018-02-17 222905.ora'
#  julia			        sistemassecuencialespaso6.png
#  julia-1.1.1-linux-aarch64      sistemassecuencialespaso6.png~
#  JuliaPro-1.1.1.1_build-37.sh   snap
#  jupyterhub_cookie_secret       Templates
# ...

# %% [markdown]
# # FIN ...
