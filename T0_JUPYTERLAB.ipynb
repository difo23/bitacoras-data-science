# %% [markdown]
# <a href="https://colab.research.google.com/github/difo23/BitacorasDataScienceDominicano/blob/master/T0_JUPYTERLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # T0-JUPYTER LAB INTRO:

# %% [markdown]
# #####  Esc, Enter, A, B, X, Shift M, Shift Enter, M, Numeros del 1 al 6 y  End o Fin.

# %% [markdown]
# Uso de funcion help()

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# Uso de ? para recibir ayuda util sobre una funcion

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
len??
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
def suma(a, b):
    return a + b

# %%
suma?
# Out:
# Signature: suma(a, b)
# Docstring: <no docstring>
# File:      ~/Documents/Notebooks/thinkstat/chapter1/T0--JUPYTER_LAB/ConceptosJupyter/<ipython-input-5-2560a4e06335>
# Type:      function

# %%
## dos ?? podemos ver el codigo

# %%
suma??
# Out:
# Signature: suma(a, b)
# Docstring: <no docstring>
# Source:
# def suma(a, b):
#     return a + b
# File:      ~/Documents/Notebooks/thinkstat/chapter1/T0--JUPYTER_LAB/ConceptosJupyter/<ipython-input-5-2560a4e06335>
# Type:      function

# %%
### Las lineas de salida de mi notebook son un arreglo llamado 'Out'
### ejemplo:

# %%
9 + 10
# Out:
# 19

# %%
20
# Out:
# 20

# %%
 # nota que In tambien es un arreglo pero es un Str
In[10]+'4'
# Out:
# '9 + 104'

# %%
Out[11]+2  
# Nota que Out es un arreglo pero es entero
# Out:
# 22

# %%
## una vista rapida a todas las utilidades del notebook con %

# %quickref
# Out:
# IPython -- An enhanced Interactive Python - Quick Reference Card
# ...
#
# obj?, obj??      : Get help, or more help for object (also works as
#                    ?obj, ??obj).
# ?foo.*abc*       : List names in 'foo' containing 'abc' in them.
# %magic           : Information about IPython's 'magic' % functions.
#
# Magic functions are prefixed by % or %%, and typically take their arguments
# without parentheses, quotes or even commas for convenience.  Line magics take a
# single % and cell magics are prefixed with two %%.
#
# Example magic function calls:
#
# %alias d ls -F   : 'd' is now an alias for 'ls -F'
# alias d ls -F    : Works if 'alias' not a python name
# alist = %alias   : Get list of aliases to 'alist'
# cd /usr/share    : Obvious. cd -<tab> to choose from visited dirs.
# %cd??            : See help AND source for magic %cd
# %timeit x=10     : time the 'x=10' statement with high precision.
# %%timeit x=2**100
# ...

# %%
# Son comandos que empiezan por % te permiten ejecurtar algunas funciones especiales
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %%
#sirve para indicar donde esta:
# %pwd
# Out:
# '/home/digdata/Documents/Notebooks/thinkstat/chapter1/T0--JUPYTER_LAB/ConceptosJupyter'

# %%
# Puedo guardar el resultado en una variable
dir = %pwd

# %%
dir
# Out:
# '/home/digdata/Documents/Notebooks/thinkstat/chapter1/T0--JUPYTER_LAB/ConceptosJupyter'

# %%
# Uso de tab

# %%
l = [1, 2, 3]#uso tab para auto completar

# %%
l.insert??
# Out:
# Docstring: L.insert(index, object) -- insert object before index
# Type:      builtin_function_or_method

# %%
l?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# list() -> new empty list
# list(iterable) -> new list initialized from iterable's items

# %%
# puedes usar tab para import tambien

# %%
import pandas

# %%
# para encotrar palabras que hagan match usas * y ? 
*Warning?
# Out:
# BytesWarning
# DeprecationWarning
# FutureWarning
# ImportWarning
# PendingDeprecationWarning
# ResourceWarning
# RuntimeWarning
# SyntaxWarning
# UnicodeWarning
# UserWarning
# Warning

# %%
str.*find?
# Out:
# str.find
# str.rfind

# %%
#Correr archivos externos usando %run

# %%
# %ls
# Out:
# myscript.py  T0-JUPYTERLAB.ipynb

# %%
# %run myscript.py
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9

# %%
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 207 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
L = [n ** 2 for n in range(1000)]

# %%
L
# Out:
# [0,
#  1,
#  4,
#  9,
#  16,
#  25,
#  36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361,
#  400,
#  441,
#  484,
#  529,
#  576,
#  625,
#  676,
#  729,
#  784,
#  841,
#  900,
#  961,
#  1024,
#  1089,
#  1156,
#  1225,
#  1296,
#  1369,
#  1444,
#  1521,
#  1600,
#  1681,
#  1764,
#  1849,
#  1936,
#  2025,
#  2116,
#  2209,
#  2304,
#  2401,
#  2500,
#  2601,
#  2704,
#  2809,
#  2916,
#  3025,
#  3136,
#  3249,
#  3364,
#  3481,
#  3600,
#  3721,
#  3844,
#  3969,
#  4096,
#  4225,
#  4356,
#  4489,
#  4624,
#  4761,
#  4900,
#  5041,
#  5184,
#  5329,
#  5476,
#  5625,
#  5776,
#  5929,
#  6084,
#  6241,
#  6400,
#  6561,
#  6724,
#  6889,
#  7056,
#  7225,
#  7396,
#  7569,
#  7744,
#  7921,
#  8100,
#  8281,
#  8464,
#  8649,
#  8836,
#  9025,
#  9216,
#  9409,
#  9604,
#  9801,
#  10000,
#  10201,
#  10404,
#  10609,
#  10816,
#  11025,
#  11236,
#  11449,
#  11664,
#  11881,
#  12100,
#  12321,
#  12544,
#  12769,
# ...

# %%
# %timeit?
# Out:
# Docstring:
# Time execution of a Python statement or expression
#
# Usage, in line mode:
#   %timeit [-n<N> -r<R> [-t|-c] -q -p<P> -o] statement
# or in cell mode:
#   %%timeit [-n<N> -r<R> [-t|-c] -q -p<P> -o] setup_code
#   code
#   code...
#
# Time execution of a Python statement or expression using the timeit
# module.  This function can be used both as a line and cell magic:
#
# - In line mode you can time a single-line statement (though multiple
#   ones can be chained with using semicolons).
#
# - In cell mode, the statement in the first line is used as setup code
#   (executed but not timed) and the body of the cell is timed.  The cell
#   body has access to any variables created in the setup code.
#
# Options:
# -n<N>: execute the given statement <N> times in a loop. If <N> is not
# provided, <N> is determined so as to get sufficient accuracy.
#
# -r<R>: number of repeats <R>, each consisting of <N> loops, and take the
# best result.
# Default: 7
#
# ...

# %%
## Uso de underscore

# %%
6 +10
# Out:
# 16

# %%
_31 # es lo mismo que decir Out[55]
# Out:
# 16

# %%
print(_) #imprime la salida anterio, en este caso la 56
# Out:
# 16

# %%
45 +12
# Out:
# 57

# %%
print(__) # Dos underscore imprime la pre anterior
# Out:
# 16

# %%
# para ver todos los comandos usandos en el Notebook

# %%
# %history
# Out:
#  # nota que In tambien es un arreglo pero es un Str
# In[10]+'4'
# help(len)
# len?
# len??
# def suma(a, b):
#     return a + b
# suma?
# ## dos ?? podemos ver el codigo
# suma??
# ### Las lineas de salida de mi notebook son un arreglo llamado 'Out'
# ### ejemplo:
# 9 + 10
# 20
#  # nota que In tambien es un arreglo pero es un Str
# In[10]+'4'
# Out[21]+2
# # Nota que Out es un arreglo pero es entero
# ## una vista rapida a todas las utilidades del notebook con %
#
# %quickref
# Out[11]+2
# # Nota que Out es un arreglo pero es entero
# ## una vista rapida a todas las utilidades del notebook con %
#
# %quickref
# # Son comandos que empiezan por % te permiten ejecurtar algunas funciones especiales
# %magic
# #sirve para indicar donde esta:
# %pwd
# # Puedo guardar el resultado en una variable
# dir = %pwd
# dir
# # Uso de tab
# l = [1, 2, 3]#uso tab para auto completar
# l.insert??
# l?
# # puedes usar tab para import tambien
# import pandas
# ...

# %%
# %history -n 1-4
# Out:
#    1:
#  # nota que In tambien es un arreglo pero es un Str
# In[10]+'4'
#    2: help(len)
#    3: len?
#    4: len??

# %%
#Usar comandos de terminal en el Notebook con !

# %%
# !echo 'hola'
# Out:
# hola

# %%
# !pwd
# Out:
# /home/digdata/Documents/Notebooks/thinkstat/chapter1/T0--JUPYTER_LAB/ConceptosJupyter

# %%
dir = !pwd

# %%
dir
# Out:
# ['/home/digdata/Documents/Notebooks/thinkstat/chapter1/T0--JUPYTER_LAB/ConceptosJupyter']

# %%
dir = %pwd

# %%
dir
# Out:
# '/home/digdata/Documents/Notebooks/thinkstat/chapter1/T0--JUPYTER_LAB/ConceptosJupyter'

# %%
archivos = !ls

# %%
archivos
# Out:
# ['myscript.py', 'T0-JUPYTERLAB.ipynb']

# %%
type(archivos)
# Out:
# IPython.utils.text.SList

# %%
archivos = %ls
# Out:
# myscript.py  T0-JUPYTERLAB.ipynb

# %%
archivos # nada se guarda

# %%
type(archivos)
# Out:
# NoneType
